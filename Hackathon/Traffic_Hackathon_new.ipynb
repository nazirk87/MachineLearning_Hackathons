# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_df=pd.read_csv("C:/Users/Nagi/Documents/Hackathon/Train.csv")
test_df=pd.read_csv("C:/Users/Nagi/Documents/Hackathon/Test.csv")

# %%
train_df["source"] = "train"
test_df["source"] = "test"
df = pd.concat([train_df,test_df])
# Out:
# C:\Users\Nagi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.dtypes
# Out:
# air_pollution_index      int64
# clouds_all               int64
# date_time               object
# dew_point                int64
# humidity                 int64
# is_holiday              object
# rain_p_h               float64
# snow_p_h               float64
# source                  object
# temperature            float64
# traffic_volume         float64
# visibility_in_miles      int64
# weather_description     object
# weather_type            object
# wind_direction           int64
# wind_speed               int64
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=[np.number])

# %%
numeric_cols.drop(['traffic_volume'],axis=1)
# Out:
#        air_pollution_index  clouds_all  dew_point  humidity  rain_p_h  \
# 0                      121          40          1        89      0.00
# 1                      178          75          1        67      0.00
# 2                      113          90          2        66      0.00
# 3                       20          90          5        66      0.00
# 4                      281          75          7        65      0.00
# 5                       23           1          6        65      0.00
# 6                      184           1          7        64      0.00
# 7                      167           1          7        64      0.00
# 8                      119          20          6        63      0.00
# 9                      161          20          3        63      0.00
# 10                     243          20          8        62      0.00
# 11                     150           1          5        62      0.00
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaled_cols = StandardScaler().fit_transform(numeric_cols)
scaled_cols
# Out:
# C:\Users\Nagi\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Nagi\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-0.40405157, -0.23996279, -1.55133786, ..., -1.55133786,
#          1.2849485 , -0.68687773],
#        [ 0.27748157,  0.65712012, -1.55133786, ..., -1.55133786,
#          1.29509933, -0.21215152],
#        [-0.49970534,  1.04158422, -1.16296761, ..., -1.16296761,
#          1.2849485 , -0.21215152],
#        ...,
#        [ 0.21769796,  1.04158422, -1.55133786, ..., -1.55133786,
#          0.36122307,  0.26257469],
#        [-1.59972374,  1.04158422,  0.77888359, ...,  0.77888359,
#          0.66574794,  2.16147952],
# ...

# %%
scaled_cols.

# %%
df.columns
# Out:
# Index(['air_pollution_index', 'clouds_all', 'date_time', 'dew_point',
#        'humidity', 'is_holiday', 'rain_p_h', 'snow_p_h', 'source',
#        'temperature', 'traffic_volume', 'visibility_in_miles',
#        'weather_description', 'weather_type', 'wind_direction', 'wind_speed'],
#       dtype='object')

# %%
category_cols = ['weather_type','is_holiday','weather_description']

# %%
scaled_df = df[scaled_cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-9ea669cc749d> in <module>
# ----> 1 scaled_df = df[scaled_cols]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ...

# %%
one_hot=pd.get_dummies(df[category_cols])
taffic_df=pd.concat([one_hot,df[scaled_cols]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-125c94e2bb2a> in <module>
#       1 one_hot=pd.get_dummies(df[category_cols])
# ----> 2 taffic_df=pd.concat([one_hot,df[scaled_cols]],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
