# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegressionRegression

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from sklearn.model_selection import train_test_split

# %%
train = pd.read_excel("Data_Train.xlsx")

# %%
train.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
test = pd.read_excel("Data_Test.xlsx")

# %%
test.head()
# Out:
#            TITLE  RESTAURANT_ID                                      CUISINES  \
# 0  CASUAL DINING           4085         North Indian, Chinese, Mughlai, Kebab
# 1    QUICK BITES          12680  South Indian, Fast Food, Pizza, North Indian
# 2  CASUAL DINING           1411       North Indian, Seafood, Biryani, Chinese
# 3           None            204                                       Biryani
# 4    QUICK BITES          13453                          South Indian, Kerala
#
#                                                 TIME       CITY      LOCALITY  \
# 0                      12noon – 12midnight (Mon-Sun)      Noida     Sector 18
# 1                            7am – 12:30AM (Mon-Sun)     Mumbai    Grant Road
# 2                           11am – 11:30pm (Mon-Sun)     Mumbai  Marine Lines
# 3  9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...  Faridabad           NIT
# 4                              11am – 10pm (Mon-Sun)      Kochi        Kaloor
#
#   RATING       VOTES
# ...

# %%
train.shape
# Out:
# (12690, 9)

# %%
test.shape
# Out:
# (4231, 8)

# %%
train["Source"] = "train"
test["Source"] = "test"
df = pd.concat([train, test])
# Out:
# C:\Users\Nagi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.shape
# Out:
# (16921, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16921 entries, 0 to 4230
# Data columns (total 10 columns):
# CITY             16774 non-null object
# COST             12690 non-null float64
# CUISINES         16921 non-null object
# LOCALITY         16793 non-null object
# RATING           16917 non-null object
# RESTAURANT_ID    16921 non-null int64
# Source           16921 non-null object
# TIME             16921 non-null object
# TITLE            16921 non-null object
# VOTES            15315 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
 df.describe().T
# Out:
#                  count         mean          std   min     25%     50%  \
# COST           12690.0   655.252246   627.003540  20.0   300.0   500.0
# RESTAURANT_ID  16921.0  7767.211631  4493.287626   0.0  3873.0  7751.0
#
#                    75%      max
# COST             800.0  14000.0
# RESTAURANT_ID  11672.0  15573.0

# %%
df.duplicated().sum()
# Out:
# 26

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (16895, 10)

# %%
df.isna().sum()
# Out:
# CITY              147
# COST             4230
# CUISINES            0
# LOCALITY          128
# RATING              4
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1602
# dtype: int64

# %%
df.shape
# Out:
# (16895, 10)

# %%
df.shape
# Out:
# (16895, 10)

# %%
df.head()
# Out:
#       CITY    COST                                    CUISINES  \
# 0    Thane  1200.0                 Malwani, Goan, North Indian
# 1  Chennai  1500.0              Asian, Modern Indian, Japanese
# 2  Chennai   800.0  North Indian, Chinese, Biryani, Hyderabadi
# 3   Mumbai   800.0                            Tibetan, Chinese
# 4   Mumbai   300.0                                    Desserts
#
#          LOCALITY RATING  RESTAURANT_ID Source  \
# 0  Dombivali East    3.6           9438  train
# 1       Ramapuram    4.2          13198  train
# 2      Saligramam    3.8          10915  train
# 3     Bandra West    4.1           6346  train
# 4     Lower Parel    3.8          15387  train
#
#                                      TIME              TITLE      VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING   49 votes
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR   30 votes
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING  221 votes
# ...

# %%
df['VOTES'] = df['VOTES'].str.extract('(\d+)', expand=False).astype(float)

# %%
df.head()
# Out:
#       CITY    COST                                    CUISINES  \
# 0    Thane  1200.0                 Malwani, Goan, North Indian
# 1  Chennai  1500.0              Asian, Modern Indian, Japanese
# 2  Chennai   800.0  North Indian, Chinese, Biryani, Hyderabadi
# 3   Mumbai   800.0                            Tibetan, Chinese
# 4   Mumbai   300.0                                    Desserts
#
#          LOCALITY RATING  RESTAURANT_ID Source  \
# 0  Dombivali East    3.6           9438  train
# 1       Ramapuram    4.2          13198  train
# 2      Saligramam    3.8          10915  train
# 3     Bandra West    4.1           6346  train
# 4     Lower Parel    3.8          15387  train
#
#                                      TIME              TITLE  VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING   49.0
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR   30.0
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING  221.0
# ...

# %%
df["CUISINES"]= df["CUISINES"].str.split(",", expand = True)

# %%
df.columns
# Out:
# Index(['CITY', 'COST', 'CUISINES', 'LOCALITY', 'RATING', 'RESTAURANT_ID',
#        'Source', 'TIME', 'TITLE', 'VOTES'],
#       dtype='object')

# %%
df.shape
# Out:
# (16895, 10)

# %%
df.head()
# Out:
#       CITY    COST      CUISINES        LOCALITY RATING  RESTAURANT_ID Source  \
# 0    Thane  1200.0       Malwani  Dombivali East    3.6           9438  train
# 1  Chennai  1500.0         Asian       Ramapuram    4.2          13198  train
# 2  Chennai   800.0  North Indian      Saligramam    3.8          10915  train
# 3   Mumbai   800.0       Tibetan     Bandra West    4.1           6346  train
# 4   Mumbai   300.0      Desserts     Lower Parel    3.8          15387  train
#
#                                      TIME              TITLE  VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING   49.0
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR   30.0
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING  221.0
# 3                 11:30am – 1am (Mon-Sun)        QUICK BITES   24.0
# 4                    11am – 1am (Mon-Sun)     DESSERT PARLOR  165.0

# %%
df.RATING.unique()
# Out:
# array(['3.6', '4.2', '3.8', '4.1', '4.0', '4.3', '3.9', '3.3', '3.4', '-',
#        '4.5', '3.5', '4.4', '2.7', '3.7', '4.7', 'NEW', '3.1', '2.5',
#        '4.6', '2.8', nan, '3.0', '3.2', '2.6', '2.9', '4.9', '4.8', '2.4',
#        '2.3', '2.0', '2.1', '2.2'], dtype=object)

# %%
new_val = df[df.RATING == 'NEW']

# %%
new_val
# Out:
#                   CITY   COST      CUISINES                      LOCALITY  \
# 62               Kochi  200.0  North Indian                   Kalamassery
# 69           New Delhi  200.0         Pizza                       Kalkaji
# 111             Mumbai  800.0      Gujarati                 Borivali West
# 117          New Delhi  500.0  North Indian                        Dwarka
# 120   Bangalore-560066  150.0  North Indian                    Whitefield
# 165             Mumbai  300.0      American                    Malad West
# 194          Bangalore  300.0  North Indian                  Marathahalli
# 212          Bangalore  300.0  South Indian                Sahakara Nagar
# 214              Thane  300.0           BBQ                     Ambernath
# 215          New Delhi  200.0     Fast Food                   Tilak Nagar
# 227        Navi Mumbai  250.0        Bihari                   CBD-Belapur
# 266              Thane  100.0        Juices                    Thane West
# ...

# %%
df= df[df.RATING != 'NEW']

# %%
df.shape
# Out:
# (15968, 10)

# %%
hyphen_val = df[df.RATING == '-']

# %%
hyphen_val.shape
# Out:
# (671, 10)

# %%
df= df[df.RATING != '-']

# %%
df.shape
# Out:
# (15297, 10)

# %%
new_val.loc[:,'RATING'] = ''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-875f368d1ed7> in <module>
# ----> 1 new_val.loc[:,'RATING'] = ''
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
new_val.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-21419a7be90c> in <module>
# ----> 1 new_val.shape
#
# AttributeError: 'str' object has no attribute 'shape'
